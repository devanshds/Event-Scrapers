# %%
import pandas as pd
import requests
import re
import json
from bs4 import BeautifulSoup as bs

# %%
base_url="https://insider.in"
url="https://insider.in/all-events-in-pune"
r=requests.get(url)
c=r.content

# %%
soup=bs(c,"html.parser")

# %%
"""Crawler to scrape all the urls from page and visit them"""
int_url = []
non_int_url = []
for link in soup.findAll('a'):
    str1=str(link.get('href'))
    if str1.endswith('/event') and str1.startswith('https:') and len(int_url)<10:
        int_url.append(link.get('href'))
    elif str1.endswith('/event') and len(int_url)<10:
        int_url.append(base_url+link.get('href'))
    elif len(int_url)==10:
        break
    else:
        non_int_url.append(base_url+link.get('href'))
df=pd.DataFrame()
df["Non Interesting URLs"]=pd.Series(non_int_url)
df["Interesting URLs"]=pd.Series(int_url)
df
# Out:
#                                  Non Interesting URLs  \
# 0                             https://insider.in/pune
# 1                           https://insider.in/movies
# 2                        https://insider.in/gameshows
# 3                        https://insider.in/monuments
# 4               https://insider.in/all-events-in-pune
# 5      https://insider.in/all-amusement-parks-in-pune
# 6               https://insider.in/all-travel-in-pune
# 7            https://insider.in/all-workshops-in-pune
# 8              https://insider.in/all-theatre-in-pune
# 9                          https://insider.in/artists
# 10                  https://insider.in/venues-in-pune
# 11   https://insider.inhttp://beaninsider.homerun.co/
# 12             https://insider.in/users/me/favourites
# 13                          https://insider.in/search
# 14                     https://insider.in/users/login
# 15                                https://insider.in#
# 16  https://insider.inhttps://insider.in/all-event...
# 17  https://insider.inhttps://insiderdotin.typefor...
# 18                                https://insider.in#
# 19              https://insider.in/all-events-in-pune
# 20        https://insider.in/all-events-in-pune-today
# 21     https://insider.in/all-events-in-pune-tomorrow
# 22      https://insider.in/all-events-in-pune-weekend
# 23              https://insider.in/all-events-in-pune
# 24       https://insider.in/all-events-in-pune/comedy
# 25       https://insider.in/all-events-in-pune/poetry
# 26        https://insider.in/all-events-in-pune/music
# 27      https://insider.in/all-events-in-pune/fitness
# 28  https://insider.in/all-events-in-pune/alternat...
# 29  https://insider.in/all-events-in-pune/experiences
# 30        https://insider.in/all-events-in-pune/games
# 31  https://insider.in/all-events-in-pune/kids-act...
# 32     https://insider.in/all-events-in-pune/open-mic
# 33      https://insider.in/all-events-in-pune/parties
# 34   https://insider.in/all-events-in-pune/activities
# 35    https://insider.in/all-events-in-pune/adventure
# 36          https://insider.in/all-events-in-pune/art
# 37  https://insider.in/all-events-in-pune/art-%26-...
# 38   https://insider.in/all-events-in-pune/conference
# 39    https://insider.in/all-events-in-pune/date-meet
# 40       https://insider.in/all-events-in-pune/events
# 41  https://insider.in/all-events-in-pune/flea-market
# 42    https://insider.in/all-events-in-pune/food-fest
# 43  https://insider.in/all-events-in-pune/house-party
# 44       https://insider.in/all-events-in-pune/movies
# 45  https://insider.in/all-events-in-pune/new-year...
# 46         https://insider.in/all-events-in-pune/pets
# 47       https://insider.in/all-events-in-pune/sports
# 48         https://insider.in/all-events-in-pune/trek
# 49    https://insider.in/all-events-in-pune/workshops
#
#                                      Interesting URLs
# 0   https://insider.in/india-bike-week-2019-dec6-7...
# 1   https://insider.in/oneplus-music-festival-nov1...
# 2         https://insider.in/zomaland-pune-2019/event
# 3   https://insider.in/bacardi-nh7-weekender-pune-...
# 4   https://insider.in/india-bike-week-2019-dec6-7...
# 5   https://insider.in/supermoon-ft-prateek-kuhad-...
# 6   https://insider.in/mentalism-special-by-suhani...
# 7   https://insider.in/eyemyth-media-arts-festival...
# 8   https://insider.in/prashasti-singh-and-samay-r...
# 9   https://insider.in/making-money-for-my-kids-by...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
""" Name, Performer,Description,startdate,enddate, Location, Price(low-high) """
l= []
for event in int_url:
    d= {}
    r=requests.get(event)
    c=r.content
    soup=bs(c,'html.parser')
    data = soup.find_all('script',{'type':'application/ld+json'})[0]
    oJson = json.loads(data.text)
    d['Event URL']=event
    d['Event Name']=oJson['name']
    d['Event Description']=bs(oJson['description']).text
    d['Performer Name']=oJson['performer']['name']
    d['Event Start DateTime']=oJson['startDate']
    d['Event End DateTime']=oJson['endDate']
    d['Location']=oJson['location']['name']
    d['Address']=oJson['location']['address']
    d['Price']='INR '+str(oJson['offers']['lowPrice'])+'-'+str(oJson['offers']['highPrice'])
    l.append(d)
df=pd.DataFrame(l)
df
# Out:
#                                            Event URL  \
# 0  https://insider.in/india-bike-week-2019-dec6-7...
# 1  https://insider.in/oneplus-music-festival-nov1...
# 2        https://insider.in/zomaland-pune-2019/event
# 3  https://insider.in/bacardi-nh7-weekender-pune-...
# 4  https://insider.in/india-bike-week-2019-dec6-7...
# 5  https://insider.in/supermoon-ft-prateek-kuhad-...
# 6  https://insider.in/mentalism-special-by-suhani...
# 7  https://insider.in/eyemyth-media-arts-festival...
# 8  https://insider.in/prashasti-singh-and-samay-r...
# 9  https://insider.in/making-money-for-my-kids-by...
#
#                                           Event Name  \
# 0                               India Bike Week 2019
# 1                       OnePlus Music Festival, 2019
# 2                                    Zomaland - Pune
# 3                   Bacardi NH7 Weekender 2019, Pune
# 4                               India Bike Week 2019
# 5  Supermoon ft. Prateek Kuhad Winter Tour 2019 -...
# 6             Mentalism Special by Suhani Shah: Pune
# 7                   EyeMyth Media Arts Festival 2019
# 8    Prashasti Singh and Samay Raina - Live in Pune!
# 9           Making Money For My Kids by Sorabh Pant
#
#                                    Event Description  \
# 0  It's more than a hobby.It's more than a passio...
# 1  A mix of prime international acts in a concert...
# 2  Come one, come all\nTo the grandest carnival o...
# 3  ​The happiest music festival is back, and we’r...
# 4  It's more than a hobby.It's more than a passio...
# 5  Abhi toh Pune show baaki hai...aur Raat Raazi ...
# 6  Suhani Shah is one of the biggest name in Indi...
# 7  EyeMyth is the only Media Arts Festival in Ind...
# 8  See one of country's top comic, supported by a...
# 9  Sorabh Pant tries new jokes to try and make mo...
#
#                        Performer Name      Event Start DateTime  \
# 0                         Seventy Emg  2019-12-06T08:30:00.000Z
# 1                             OnePlus  2019-11-16T08:30:00.000Z
# 2                              Zomato  2019-11-15T06:30:00.000Z
# 3                                 OML  2019-11-29T09:30:00.000Z
# 4                         Seventy Emg  2019-12-06T08:30:00.000Z
# 5  Zee Entertainment Enterprises Ltd.  2019-12-12T14:30:00.000Z
# 6                                 OML  2019-11-16T13:00:00.000Z
# 7                               Unbox  2019-11-29T04:00:00.000Z
# 8                 Spade Entertainment  2019-11-14T14:30:00.000Z
# 9                                 OML  2019-11-15T14:30:00.000Z
#
#          Event End DateTime                               Location  \
# 0  2019-12-07T16:30:00.000Z      Little Vagator Hills, Bardez, Goa
# 1  2019-11-16T16:30:00.000Z                     D.Y. Patil Stadium
# 2  2019-11-15T16:30:00.000Z                      Royal Palms, Pune
# 3  2019-12-01T16:30:00.000Z  Mahalakshmi Lawns, Pune, Airport Area
# 4  2019-12-07T16:30:00.000Z      Little Vagator Hills, Bardez, Goa
# 5  2019-12-12T17:30:00.000Z                      Royal Palms, Pune
# 6  2019-11-16T14:30:00.000Z              Classic Rock Kalyaninagar
# 7  2019-12-01T18:29:00.000Z             Deepak Cinema, Lower Parel
# 8  2019-11-14T16:00:00.000Z                      Spade Comedy Club
# 9  2019-11-15T15:50:00.000Z                      Spade Comedy Club
#
#                                              Address           Price
# 0      Ozran Beach Road, Bardez, Vagator, Goa 403509    INR 600-2500
# 1  Dy Patil Vidyanagar Campus 4 B Sector 7, Nerul...  INR 500-200000
# 2  84/36, N Main Rd, Koregaon Park Annexe, Mundhw...     INR 100-599
# 3  Nagar Road, Near Kharadi Bypass, Opp Lohagaon-...    INR 100-5500
# 4      Ozran Beach Road, Bardez, Vagator, Goa 403509    INR 600-2500
# 5  84/36, N Main Rd, Koregaon Park Annexe, Mundhw...    INR 750-6500
# 6  Mulik Capital, Kalyani Nagar, Pune, Maharashtr...     INR 499-499
# 7  Deepak Cinema, N M The Deepak, 38, NM Joshi Ma...  INR 3000-15000
# 8  Kogobo Resto Bar & Banquet Baner, 4th Floor, T...     INR 499-499
# 9  Kogobo Resto Bar & Banquet Baner, 4th Floor, T...     INR 299-399

# %%
df.to_csv('insider.csv')
