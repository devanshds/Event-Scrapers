# %%
import pandas as pd
import sqlite3 as sql
import requests
import re
import json
from bs4 import BeautifulSoup as bs

# %%
"""Establishing Connection"""
url="https://naadyogacouncil.com/events/list/?tribe_event_display=past&tribe_paged="
conn=sql.connect("Events.db")
cur=conn.cursor()

# %%
"""Creating Table and assigning UNIQUE constraint to EventURL to prevent duplicate records"""
cur.execute("CREATE TABLE IF NOT EXISTS int_url3 (id INTEGER PRIMARY KEY, EventURL TEXT, Name TEXT, Description TEXT, StartDate TEXT, EndDate TEXT, Address TEXT, OrganizerName TEXT, OrganizerPhone TEXT, OrganizerEmail TEXT)")
cur.execute("SELECT * FROM int_url3")
try:
    cur.execute("CREATE UNIQUE INDEX int_url3_EventURL on int_url3 ( EventURL )")
except:
    pass
print(*cur.fetchall(), sep='\n')

# %%
"""Crawler to crawl through all the pages of event until 10 Interesting URLs are found"""
int_url = []
non_int_url = []
for i in range(1,10):
    r=requests.get(url+str(i))
    c=r.content
    soup=bs(c,"html.parser")
    for link in soup.find_all('a'):
        if '/event/' in link.get('href') and len(int_url)<10:
            if link.get('href') not in int_url:
                int_url.append(link.get('href'))
            else:
                pass
        elif len(int_url)==10:
            break
        else:
            if link.get('href') not in non_int_url:
                non_int_url.append(link.get('href'))
            else:
                pass
    else:
        continue
    break
df=pd.DataFrame()
df["Non Interesting URLs"]=pd.Series(non_int_url)
df["Interesting URLs"]=pd.Series(int_url)
df
# Out:
#                                  Non Interesting URLs  \
# 0                         https://naadyogacouncil.com
# 1                        https://naadyogacouncil.com/
# 2               https://naadyogacouncil.com/about-us/
# 3        https://naadyogacouncil.com/our-aspirations/
# 4          https://naadyogacouncil.com/meet-our-team/
# 5      https://naadyogacouncil.com/what-is-naad-yoga/
# 6                  http://naadyogacouncil.com/events/
# 7   https://naadyogacouncil.com/teacher-training/c...
# 8         https://naadyogacouncil.com/weekly-classes/
# 9   https://naadyogacouncil.com/healing-sound-course/
# 10  https://naadyogacouncil.com/sound-therapist-co...
# 11          https://naadyogacouncil.com/publications/
# 12      https://naadyogacouncil.com/european-centres/
# 13  https://naadyogacouncil.com/tree-project-grow-...
# 14    https://naadyogacouncil.com/friends-supporters/
# 15              https://naadyogacouncil.com/articles/
# 16  https://naadyogacouncil.com/events/list/?tribe...
# 17  https://maps.google.com/maps?f=q&source=s_q&hl...
# 18  https://maps.google.com/maps?f=q&source=s_q&hl...
# 19  https://maps.google.com/maps?f=q&source=s_q&hl...
# 20  https://maps.google.com/maps?f=q&source=s_q&hl...
# 21  https://maps.google.com/maps?f=q&source=s_q&hl...
#
#                                      Interesting URLs
# 0   https://naadyogacouncil.com/event/naad-yoga-te...
# 1   https://naadyogacouncil.com/event/heartspace-s...
# 2   https://naadyogacouncil.com/event/naad-yoga-te...
# 3   https://naadyogacouncil.com/event/naad-yoga-te...
# 4   https://naadyogacouncil.com/event/heartspace-s...
# 5   https://naadyogacouncil.com/event/naad-yoga-te...
# 6   https://naadyogacouncil.com/event/sound-therap...
# 7   https://naadyogacouncil.com/event/naad-yoga-te...
# 8   https://naadyogacouncil.com/event/heartspace-s...
# 9   https://naadyogacouncil.com/event/heartspace-s...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN

# %%
"""Scraper to scrape the relevant data out of each URL
url,Name,Description,startdate,enddate,location,organizer,telephone,email



"""
l= []
for event in int_url:
    d= {}
    r=requests.get(event)
    c=r.content
    soup=bs(c,'html.parser')
    data = soup.find_all('script',{'type':'application/ld+json'})
    oJson = json.loads(data[1].text)[0]
    d['Event URL']=event
    d['Name']=bs(oJson['name']).text
    clean = re.compile('<.*?>')
    d['Description']=re.sub(clean, '',bs(oJson['description']).text )
    d['Start Date']=oJson['startDate']
    d['End Date']=oJson['endDate']
    try:
        d['Address']=oJson['location']['address']['streetAddress']+','+oJson['location']['address']['addressLocality']+','+oJson['location']['address']['addressCountry']+','+oJson['location']['address']['postalCode']
    except:
        d['Address']="Address Incomplete"
    d['Organizer Name']=oJson['organizer']['name']
    d['Organizer Phone']=oJson['organizer']['telephone']
    d['Organizer Email']=bs(oJson['organizer']['email']).text
    l.append(d)
    
    # Inserts into the table
    cur.execute("INSERT INTO int_url3 VALUES (NULL, ?, ?, ?, ?, ?, ?, ?, ?, ?)",(d["Event URL"],d["Name"],d["Description"],d["Start Date"],d["End Date"],d["Address"],d["Organizer Name"],d["Organizer Phone"],d["Organizer Email"]))

df=pd.DataFrame(l)
df
# Out:
#                                            Event URL  \
# 0  https://naadyogacouncil.com/event/naad-yoga-te...
# 1  https://naadyogacouncil.com/event/heartspace-s...
# 2  https://naadyogacouncil.com/event/naad-yoga-te...
# 3  https://naadyogacouncil.com/event/naad-yoga-te...
# 4  https://naadyogacouncil.com/event/heartspace-s...
# 5  https://naadyogacouncil.com/event/naad-yoga-te...
# 6  https://naadyogacouncil.com/event/sound-therap...
# 7  https://naadyogacouncil.com/event/naad-yoga-te...
# 8  https://naadyogacouncil.com/event/heartspace-s...
# 9  https://naadyogacouncil.com/event/heartspace-s...
#
#                                                 Name  \
# 0               Naad Yoga Teacher Training Barcelona
# 1          HeartSpace – Sound Meditation & Naad Yoga
# 2  Naad Yoga Teacher Training Spain with Manjeet ...
# 3  Naad Yoga Teacher Training Germany with Niranj...
# 4          HeartSpace – Sound Meditation & Naad Yoga
# 5  Naad Yoga Teacher Training Hamburg with Veer Kaur
# 6  Sound Therapist Course with Yogi of Sound Prof...
# 7  Naad Yoga Teacher Training Germany with Sidak ...
# 8          HeartSpace – Sound Meditation & Naad Yoga
# 9          HeartSpace – Sound Meditation & Naad Yoga
#
#                                          Description  \
# 0  A journey from stress to success: understandin...
# 1  Free your voice - Create balance between Mind,...
# 2  A journey from stress to success: understandin...
# 3  A journey from stress to success: understandin...
# 4  Free your voice - Create balance between Mind,...
# 5  A journey from stress to success: understandin...
# 6  Learn how to heal with sound! Understand the a...
# 7  A journey from stress to success: understandin...
# 8  Free your voice - Create balance between Mind,...
# 9  Free your voice - Create balance between Mind,...
#
#                   Start Date                   End Date  \
# 0  2019-09-08T00:00:00+02:00  2019-09-08T23:59:59+02:00
# 1  2019-09-27T17:30:00+02:00  2019-09-27T18:30:00+02:00
# 2  2019-09-28T00:00:00+02:00  2019-09-28T23:59:59+02:00
# 3  2019-09-28T00:00:00+02:00  2019-09-28T23:59:59+02:00
# 4  2019-10-04T17:00:00+02:00  2019-10-04T18:00:00+02:00
# 5  2019-10-05T00:00:00+02:00  2019-10-06T23:59:59+02:00
# 6  2019-10-06T00:00:00+02:00  2019-10-06T23:59:59+02:00
# 7  2019-10-12T00:00:00+02:00  2019-10-13T23:59:59+02:00
# 8  2019-10-18T17:00:00+02:00  2019-10-18T18:00:00+02:00
# 9  2019-11-01T17:00:00+02:00  2019-11-01T18:00:00+02:00
#
#                                            Address     Organizer Name  \
# 0              C/Mestral 13 B,Vidreres,Spain,17411          Guru Kaur
# 1  27 Endell Street,London,United Kingdom,WC2H 9BA     Satpurakh Kaur
# 2                               Address Incomplete       Manjeet Kaur
# 3                               Address Incomplete      Niranjan Kaur
# 4  27 Endell Street,London,United Kingdom,WC2H 9BA     Satpurakh Kaur
# 5                               Address Incomplete          Veer Kaur
# 6                               Address Incomplete   Jiwan Mukh Singh
# 7       Gebhardtstrasse 33,Karlsruhe,Germany,76135  Sidak Kaur Khalsa
# 8  27 Endell Street,London,United Kingdom,WC2H 9BA     Satpurakh Kaur
# 9  27 Endell Street,London,United Kingdom,WC2H 9BA     Satpurakh Kaur
#
#      Organizer Phone                Organizer Email
# 0   0034 669 292 452        besound.laura@gmail.com
# 1                     satpurakh (at) rajacademy.com
# 2          645799531     manjeet.naadyoga@gmail.com
# 3    0049 1744778067        niranjan@rajacademy.com
# 4                     satpurakh (at) rajacademy.com
# 5  0049 152 14511437             verenatimm@gmx.net
# 6                         jiwanmukhsingh@hotmail.es
# 7    0157 789 420 43         sidak@naadyogaklang.de
# 8                     satpurakh (at) rajacademy.com
# 9                     satpurakh (at) rajacademy.com

# %%
"""Displaying records from the SQL database"""
cur.execute("SELECT * FROM int_url3")
rows=cur.fetchall()
print(*rows, sep = "\n")
# Out:
# (1, 'https://naadyogacouncil.com/event/naad-yoga-teacher-training-barcelona/', 'Naad Yoga Teacher Training Barcelona', 'A journey from stress to success: understanding how our emotional state is composed and then consciously converting negativity to positivity creates a happy and healthy life. The process is similar to the composition of music and Naad Yoga uses musical modes and our own emotions as raw material for personal development. In this three-year programme, […]\\n', '2019-09-08T00:00:00+02:00', '2019-09-08T23:59:59+02:00', 'C/Mestral 13 B,Vidreres,Spain,17411', 'Guru Kaur', '0034 669 292 452', 'besound.laura@gmail.com')
# (2, 'https://naadyogacouncil.com/event/heartspace-sound-meditation-naad-yoga/', 'HeartSpace – Sound Meditation & Naad Yoga', 'Free your voice - Create balance between Mind, Body & Soul \xa0 Naad Yoga - The Yoga of Sound: Naad Yoga is a deeply transformative process using active listening, singing, breath & rhythm, mantras and mudras. Through Naad Yoga we can reconnect with our emotions, release stress and trauma and return to a state of […]\\n', '2019-09-27T17:30:00+02:00', '2019-09-27T18:30:00+02:00', '27 Endell Street,London,United Kingdom,WC2H 9BA', 'Satpurakh Kaur', '', 'satpurakh (at) rajacademy.com')
# (3, 'https://naadyogacouncil.com/event/naad-yoga-teacher-training-guru-kaur-maurice-diaz/', 'Naad Yoga Teacher Training Spain with Manjeet Kaur', 'A journey from stress to success: understanding how our emotional state is composed and then consciously converting negativity to positivity creates a happy and healthy life. The process is similar to the composition of music and Naad Yoga uses musical modes and our own emotions as raw material for personal development. In this three-year programme, […]\\n', '2019-09-28T00:00:00+02:00', '2019-09-28T23:59:59+02:00', 'Address Incomplete', 'Manjeet Kaur', '645799531', 'manjeet.naadyoga@gmail.com')
# (4, 'https://naadyogacouncil.com/event/naad-yoga-teacher-training-germany-niranjan-kaur/', 'Naad Yoga Teacher Training Germany with Niranjan Kaur', 'A journey from stress to success: understanding how our emotional state is composed and then consciously converting negativity to positivity creates a happy and healthy life. The process is similar to the composition of music and Naad Yoga uses musical modes and our own emotions as raw material for personal development. In this three-year programme, […]\\n', '2019-09-28T00:00:00+02:00', '2019-09-28T23:59:59+02:00', 'Address Incomplete', 'Niranjan Kaur', '0049 1744778067', 'niranjan@rajacademy.com')
# (5, 'https://naadyogacouncil.com/event/heartspace-sound-meditation-naad-yoga-2/', 'HeartSpace – Sound Meditation & Naad Yoga', 'Free your voice - Create balance between Mind, Body & Soul \xa0 Naad Yoga - The Yoga of Sound: Naad Yoga is a deeply transformative process using active listening, singing, breath & rhythm, mantras and mudras. Through Naad Yoga we can reconnect with our emotions, release stress and trauma and return to a state of […]\\n', '2019-10-04T17:00:00+02:00', '2019-10-04T18:00:00+02:00', '27 Endell Street,London,United Kingdom,WC2H 9BA', 'Satpurakh Kaur', '', 'satpurakh (at) rajacademy.com')
# (6, 'https://naadyogacouncil.com/event/naad-yoga-teacher-training-germany-veer-kaur/', 'Naad Yoga Teacher Training Hamburg with Veer Kaur', 'A journey from stress to success: understanding how our emotional state is composed and then consciously converting negativity to positivity creates a happy and healthy life. The process is similar to the composition of music and Naad Yoga uses musical modes and our own emotions as raw material for personal development. In this three-year programme, […]\\n', '2019-10-05T00:00:00+02:00', '2019-10-06T23:59:59+02:00', 'Address Incomplete', 'Veer Kaur', '0049 152 14511437', 'verenatimm@gmx.net')
# (7, 'https://naadyogacouncil.com/event/sound-therapist-course-with-yogi-of-sound-prof-surinder-singh-2/', 'Sound Therapist Course with Yogi of Sound Prof. Surinder Singh', 'Learn how to heal with sound! Understand the applied science of sound therapy and explore how deeply sound influences our emotions. Using the techniques and practices of ancient Indian Naad Yoga, discover the power of sound, map the dynamics of your expression and experience your inner Naad. STARTING IN SPAIN in October 2019 (details below, […]\\n', '2019-10-06T00:00:00+02:00', '2019-10-06T23:59:59+02:00', 'Address Incomplete', 'Jiwan Mukh Singh', '', 'jiwanmukhsingh@hotmail.es')
# (8, 'https://naadyogacouncil.com/event/naad-yoga-teacher-training-germany-2/', 'Naad Yoga Teacher Training Germany with Sidak Kaur', 'A journey from stress to success: understanding how our emotional state is composed and then consciously converting negativity to positivity creates a happy and healthy life. The process is similar to the composition of music and Naad Yoga uses musical modes and our own emotions as raw material for personal development. In this three-year programme, […]\\n', '2019-10-12T00:00:00+02:00', '2019-10-13T23:59:59+02:00', 'Gebhardtstrasse 33,Karlsruhe,Germany,76135', 'Sidak Kaur Khalsa', '0157 789 420 43', 'sidak@naadyogaklang.de')
# (9, 'https://naadyogacouncil.com/event/heartspace-sound-meditation-naad-yoga-3/', 'HeartSpace – Sound Meditation & Naad Yoga', 'Free your voice - Create balance between Mind, Body & Soul \xa0 Naad Yoga - The Yoga of Sound: Naad Yoga is a deeply transformative process using active listening, singing, breath & rhythm, mantras and mudras. Through Naad Yoga we can reconnect with our emotions, release stress and trauma and return to a state of […]\\n', '2019-10-18T17:00:00+02:00', '2019-10-18T18:00:00+02:00', '27 Endell Street,London,United Kingdom,WC2H 9BA', 'Satpurakh Kaur', '', 'satpurakh (at) rajacademy.com')
# (10, 'https://naadyogacouncil.com/event/heartspace-sound-meditation-naad-yoga-4/', 'HeartSpace – Sound Meditation & Naad Yoga', 'Free your voice - Create balance between Mind, Body & Soul \xa0 Naad Yoga - The Yoga of Sound: Naad Yoga is a deeply transformative process using active listening, singing, breath & rhythm, mantras and mudras. Through Naad Yoga we can reconnect with our emotions, release stress and trauma and return to a state of […]\\n', '2019-11-01T17:00:00+02:00', '2019-11-01T18:00:00+02:00', '27 Endell Street,London,United Kingdom,WC2H 9BA', 'Satpurakh Kaur', '', 'satpurakh (at) rajacademy.com')

# %%
"""Closing Connection"""
conn.commit()
conn.close()

df.to_csv('nyc.csv')
